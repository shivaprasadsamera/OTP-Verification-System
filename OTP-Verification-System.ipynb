# %%
import smtplib
import random
from email.message import EmailMessage

def generate_code():
    return str(random.randint(100000, 999999))

def send_email(receiver_email, code):
    sender_email = "shivaprasadsamera247@gmail.com"
    sender_password = "lkcf itqm zwnc jdmz"

    msg = EmailMessage()
    msg.set_content(f"Your verification code is: {code}")
    msg["Subject"] = "Your Verification Code"
    msg["From"] = sender_email
    msg["To"] = receiver_email

    try:
        with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
            smtp.login(sender_email, sender_password)
            smtp.send_message(msg)
        print("Verification code sent!")
    except Exception as e:
        print(f"Error sending email: {e}")

def verify_email():
    email = input("Enter your email address: ")
    code = generate_code()
    send_email(email, code)

    attempts = 3
    while attempts > 0:
        user_input = input("Enter the verification code sent to your email: ")
        if user_input == code:
            print("✅ Verification successful!")
            return
        else:
            attempts -= 1
            if attempts > 0:
                print(f"❌ Incorrect code. You have {attempts} attempt(s) left.")
            else:
                print("🚫 Too many incorrect attempts. Verification failed.")

if __name__ == "__main__":
    verify_email()
